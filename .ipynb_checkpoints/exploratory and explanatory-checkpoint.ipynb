# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

customer_df = pd.read_csv("customer.csv")
order_df = pd.read_csv("order.csv")
product_df = pd.read_csv("product.csv")
sales_df = pd.read_csv("sales.csv")

# %%
customer_df.describe(include="all")
# Out:
#          Unnamed: 0  customer_id customer_name             gender  \
# count   1001.000000  1001.000000          1001               1001
# unique          NaN          NaN          1000                  3
# top             NaN          NaN     fulan 943  Prefer not to say
# freq            NaN          NaN             2                743
# mean     501.895105   500.942058           NaN                NaN
# std      290.944352   289.013599           NaN                NaN
# min        0.000000     1.000000           NaN                NaN
# 25%      250.000000   251.000000           NaN                NaN
# 50%      501.000000   501.000000           NaN                NaN
# 75%      753.000000   751.000000           NaN                NaN
# max     1006.000000  1000.000000           NaN                NaN
#
#                 age                home_address     zip_code     city  \
# count   1001.000000                        1001  1001.000000     1001
# unique          NaN                        1000          NaN      961
# top             NaN  3117 Heller PlaceSuite 149          NaN  New Ava
# freq            NaN                           2          NaN        3
# mean      49.874126                         NaN  5000.693307      NaN
# std       17.644663                         NaN  2886.084454      NaN
# min       20.000000                         NaN     2.000000      NaN
# 25%       34.000000                         NaN  2398.000000      NaN
# 50%       50.000000                         NaN  5079.000000      NaN
# 75%       65.000000                         NaN  7454.000000      NaN
# max       80.000000                         NaN  9998.000000      NaN
#
#                   state    country
# count              1001       1001
# unique                8          1
# top     South Australia  Australia
# freq                140       1001
# mean                NaN        NaN
# std                 NaN        NaN
# min                 NaN        NaN
# 25%                 NaN        NaN
# 50%                 NaN        NaN
# 75%                 NaN        NaN
# max                 NaN        NaN

# %%
# melihat demografi pelanggan berdasarkan gender (PIVOT table)
customer_df.groupby(by="gender").agg({
    "customer_id": "nunique",
    "age": ["min", "max", "mean", "std"]
})
# Out:
#                   customer_id age
#                       nunique min max       mean        std
# gender
# Female                    115  20  79  49.147826  16.646607
# Male                      143  20  80  51.230769  18.462635
# Prefer not to say         742  20  80  49.725437  17.644283

# %%
# melihat persebaran customer berdasarkan kota dan negara bagian
customer_df.groupby(by="city").customer_id.nunique().sort_values(ascending=False)
# Out:
# city
# East Aidan       3
# East Sophia      3
# New Ava          3
# West Jackfort    2
# Corkeryshire     2
#                 ..
# Jordanside       1
# Josephland       1
# Josephmouth      1
# Justinport       1
# Zacville         1
# Name: customer_id, Length: 961, dtype: int64

# %%
customer_df.groupby(by="state").customer_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               124
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %%
# explore order_df with get delivery_time
order_df["delivery_date"] = pd.to_datetime(order_df["delivery_date"])
order_df["order_date"] = pd.to_datetime(order_df["order_date"])

delivery_time = order_df["delivery_date"] - order_df["order_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
order_df["delivery_time"] = round(delivery_time / 86400)

# %%
order_df
# Out:
#      Unnamed: 0  order_id  customer_id  payment order_date delivery_date  \
# 0             0         1           64    30811 2021-08-30    2021-09-24
# 1             1         2          473    50490 2021-02-03    2021-02-13
# 2             2         3          774    46763 2021-10-08    2021-11-03
# 3             3         4          433    39782 2021-05-06    2021-05-19
# 4             4         5          441    14719 2021-03-23    2021-03-24
# ..          ...       ...          ...      ...        ...           ...
# 995         995       996          345    37843 2021-01-13    2021-02-02
# 996         996       997          346    53831 2021-01-18    2021-01-31
# 997         997       998          407    53308 2021-05-05    2021-05-21
# 998         998       999          428    31643 2021-06-15    2021-07-12
# 999         999      1000          896    27836 2021-04-07    2021-04-24
#
#      delivery_time
# 0             25.0
# 1             10.0
# 2             26.0
# 3             13.0
# 4              1.0
# ..             ...
# 995           20.0
# 996           13.0
# 997           16.0
# 998           27.0
# 999           17.0
#
# [1000 rows x 7 columns]

# %%
order_df.describe(include="all")
# Out:
#         Unnamed: 0     order_id  customer_id       payment  \
# count  1000.000000  1000.000000  1000.000000   1000.000000
# mean    499.500000   500.500000   506.640000  33972.936000
# min       0.000000     1.000000     1.000000  10043.000000
# 25%     249.750000   250.750000   275.250000  21329.250000
# 50%     499.500000   500.500000   515.000000  33697.500000
# 75%     749.250000   750.250000   737.250000  46249.000000
# max     999.000000  1000.000000  1000.000000  59910.000000
# std     288.819436   288.819436   277.115502  14451.609047
#
#                        order_date        delivery_date  delivery_time
# count                        1000                 1000    1000.000000
# mean   2021-05-27 18:38:52.800000  2021-06-10 20:31:12      14.078000
# min           2021-01-01 00:00:00  2021-01-03 00:00:00       1.000000
# 25%           2021-03-13 18:00:00  2021-03-28 00:00:00       8.000000
# 50%           2021-05-27 12:00:00  2021-06-11 12:00:00      14.000000
# 75%           2021-08-12 06:00:00  2021-08-24 06:00:00      21.000000
# max           2021-10-24 00:00:00  2021-11-20 00:00:00      27.000000
# std                           NaN                  NaN       7.707225

# %%
# membuat tabel customer yang pernah order dan belum
customer_id_in_order_df = order_df.customer_id.tolist()
customer_df["status"] = customer_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_order_df else "Non Active")
customer_df.sample(10)
# Out:
#      Unnamed: 0  customer_id customer_name             gender  age  \
# 319         320          320     fulan 320  Prefer not to say   43
# 186         186          187     fulan 187  Prefer not to say   70
# 578         580          579     fulan 579             Female   45
# 346         347          347     fulan 347             Female   20
# 419         420          420     fulan 420  Prefer not to say   44
# 945         951          945     fulan 945  Prefer not to say   48
# 850         854          851     fulan 851  Prefer not to say   71
# 571         573          572     fulan 572  Prefer not to say   27
# 993         999          993     fulan 993  Prefer not to say   24
# 814         818          815     fulan 815             Female   34
#
#                      home_address  zip_code                  city  \
# 319   83 Reynolds ParadeSuite 974       299             Howehaven
# 186  30 Williamson SummitApt. 594      1007        West Isabelton
# 578     70 Anthony DriveSuite 124      9043            Bauchhaven
# 346     16 Maddison MewsSuite 093      1435             Levihaven
# 419        10 Harry MewsSuite 632      5547            Jonesville
# 945   8307 Matthew GroveSuite 475      3606          Stantonmouth
# 850       71 Joseph TrailApt. 169      6648       North Emmashire
# 571         12 Nate RidgeApt. 107      7611            Sanfordton
# 993       327 Abby CircleApt. 055       536           Michaelberg
# 814     063 Joseph CrestSuite 060      8626  Port Jonathanchester
#
#                             state    country      status
# 319                      Tasmania  Australia      Active
# 186                    Queensland  Australia      Active
# 578               South Australia  Australia  Non Active
# 346                      Victoria  Australia      Active
# 419                      Tasmania  Australia  Non Active
# 945  Australian Capital Territory  Australia      Active
# 850  Australian Capital Territory  Australia      Active
# 571               South Australia  Australia      Active
# 993                      Victoria  Australia      Active
# 814               South Australia  Australia  Non Active

# %%
# make pivot table to count active and non active customer
customer_df.groupby("status").customer_id.count()
# Out:
# status
# Active        617
# Non Active    384
# Name: customer_id, dtype: int64

# %%
# join left order_df and customer_df
order_customer_df = pd.merge(
    left=order_df,
    right=customer_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)

# %%
order_customer_df.drop(["Unnamed: 0_y", "Unnamed: 0_x"], axis=1)
# Out:
#      order_id  customer_id  payment order_date delivery_date  delivery_time  \
# 0           1           64    30811 2021-08-30    2021-09-24           25.0
# 1           2          473    50490 2021-02-03    2021-02-13           10.0
# 2           3          774    46763 2021-10-08    2021-11-03           26.0
# 3           4          433    39782 2021-05-06    2021-05-19           13.0
# 4           5          441    14719 2021-03-23    2021-03-24            1.0
# ..        ...          ...      ...        ...           ...            ...
# 995       996          345    37843 2021-01-13    2021-02-02           20.0
# 996       997          346    53831 2021-01-18    2021-01-31           13.0
# 997       998          407    53308 2021-05-05    2021-05-21           16.0
# 998       999          428    31643 2021-06-15    2021-07-12           27.0
# 999      1000          896    27836 2021-04-07    2021-04-24           17.0
#
#     customer_name             gender  age                   home_address  \
# 0        fulan 64  Prefer not to say   75      4927 Alice MeadowApt. 960
# 1       fulan 473               Male   61  531 Schmitt BoulevardApt. 010
# 2       fulan 774  Prefer not to say   34       2096 Wilson MewsApt. 714
# 3       fulan 433  Prefer not to say   46        5777 Mayer PassApt. 881
# 4       fulan 441  Prefer not to say   53   33 Richards JunctionApt. 478
# ..            ...                ...  ...                            ...
# 995     fulan 345  Prefer not to say   62      9182 Hermann MallApt. 890
# 996     fulan 346  Prefer not to say   40    59 Bergstrom GroveSuite 260
# 997     fulan 407               Male   41      5233 Lara AvenueSuite 291
# 998     fulan 428  Prefer not to say   66      80 Hermiston WaySuite 403
# 999     fulan 896  Prefer not to say   67     985 Nguyen TerraceApt. 362
#
#      zip_code                city                         state    country  \
# 0        7787      Sanfordborough               South Australia  Australia
# 1        1744             Annaton               South Australia  Australia
# 2        8590  West Jonathanshire                      Tasmania  Australia
# 3        9728    West Michaelport                      Tasmania  Australia
# 4        7650     South Rileyview             Western Australia  Australia
# ..        ...                 ...                           ...        ...
# 995       799          Audreyfurt                      Victoria  Australia
# 996      6060           Olsonbury            Northern Territory  Australia
# 997      8697       Hartmannshire                    Queensland  Australia
# 998      1112      North Liamfort  Australian Capital Territory  Australia
# 999      7737            Ryanberg               South Australia  Australia
#
#      status
# 0    Active
# 1    Active
# 2    Active
# 3    Active
# 4    Active
# ..      ...
# 995  Active
# 996  Active
# 997  Active
# 998  Active
# 999  Active
#
# [1000 rows x 15 columns]

# %%
# order total based on city
order_customer_df.groupby("city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                city  order_id
# 0        Jordanside         6
# 1           New Ava         6
# 2         Lake Rose         5
# 3        O'keefeton         5
# 4          East Max         5
# 5  Port Hannahburgh         5
# 6          Rubyfort         5
# 7          West Kai         5
# 8     Andrewborough         4
# 9     Port Aaronton         4

# %%
# orders total based on state
order_customer_df.groupby("state").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                           state  order_id
# 0               South Australia       148
# 1                    Queensland       139
# 2             Western Australia       130
# 3               New South Wales       129
# 4  Australian Capital Territory       118
# 5                      Victoria       118
# 6                      Tasmania       112
# 7            Northern Territory       106

# %%
# order based on gender
order_customer_df.groupby("gender").order_id.nunique().sort_values(ascending=False)
# Out:
# gender
# Prefer not to say    725
# Female               139
# Male                 136
# Name: order_id, dtype: int64

# %%
# make age_group column
order_customer_df["age_group"] = order_customer_df.age.apply(lambda x: "Youth" if x <= 24 else ("Senior" if x > 64 else "Adult"))

# %%
order_customer_df.groupby("age_group").order_id.nunique().sort_values(ascending=False)
# Out:
# age_group
# Adult     681
# Senior    226
# Youth      93
# Name: order_id, dtype: int64

# %%
product_df.describe(include="all")
# Out:
#          Unnamed: 0   product_id product_type product_name  size colour  \
# count   1260.000000  1260.000000         1260         1260  1260   1260
# unique          NaN          NaN            3           35     8      7
# top             NaN          NaN        Shirt        Denim    XS    red
# freq            NaN          NaN          420           70   252    180
# mean     633.709524   629.500000          NaN          NaN   NaN    NaN
# std      365.875949   363.874979          NaN          NaN   NaN    NaN
# min        0.000000     0.000000          NaN          NaN   NaN    NaN
# 25%      316.750000   314.750000          NaN          NaN   NaN    NaN
# 50%      635.500000   629.500000          NaN          NaN   NaN    NaN
# 75%      950.250000   944.250000          NaN          NaN   NaN    NaN
# max     1265.000000  1259.000000          NaN          NaN   NaN    NaN
#
#               price     quantity                                   description
# count   1260.000000  1260.000000                                          1260
# unique          NaN          NaN                                          1260
# top             NaN          NaN  A red coloured, XS sized, Oxford Cloth Shirt
# freq            NaN          NaN                                             1
# mean     105.805556    60.150000                                           NaN
# std        9.704423    11.670573                                           NaN
# min       90.000000    40.000000                                           NaN
# 25%       95.750000    50.000000                                           NaN
# 50%      108.500000    60.000000                                           NaN
# 75%      114.000000    70.000000                                           NaN
# max      119.000000    80.000000                                           NaN

# %%
sales_df.describe(include="all")
# Out:
#         Unnamed: 0     sales_id     order_id   product_id  price_per_unit  \
# count  5000.000000  5000.000000  5000.000000  5000.000000     5000.000000
# mean   2499.500000  2499.500000   503.038200   634.053200      103.501600
# std    1443.520003  1443.520003   285.964418   363.255794        9.195004
# min       0.000000     0.000000     1.000000     1.000000       90.000000
# 25%    1249.750000  1249.750000   258.000000   323.000000       95.000000
# 50%    2499.500000  2499.500000   504.500000   635.000000      102.000000
# 75%    3749.250000  3749.250000   749.000000   951.000000      112.000000
# max    4999.000000  4999.000000   999.000000  1259.000000      119.000000
#
#          quantity  total_price
# count  5000.00000  5000.000000
# mean      1.99240   206.360000
# std       0.80751    86.357457
# min       1.00000    90.000000
# 25%       1.00000   112.000000
# 50%       2.00000   204.000000
# 75%       3.00000   285.000000
# max       3.00000   357.000000

# %%
# look the most expensive and chip in product_df
product_df.sort_values(by="price", ascending=False)
# Out:
#       Unnamed: 0  product_id product_type product_name size  colour  price  \
# 698          704         698       Jacket        Parka    L  violet    119
# 665          671         665       Jacket        Parka   XS     red    119
# 692          698         692       Jacket        Parka    M  indigo    119
# 693          699         693       Jacket        Parka    L  indigo    119
# 694          700         694       Jacket        Parka   XL  indigo    119
# ...          ...         ...          ...          ...  ...     ...    ...
# 1219        1225        1219     Trousers      Pleated   XL  indigo     90
# 1220        1226        1220     Trousers      Pleated   XS  violet     90
# 1221        1227        1221     Trousers      Pleated    S  violet     90
# 1222        1228        1222     Trousers      Pleated    M  violet     90
# 593          599         593       Jacket       Bomber    L  violet     90
#
#       quantity                                    description
# 698         53       A violet coloured, L sized, Parka Jacket
# 665         65         A red coloured, XS sized, Parka Jacket
# 692         66       A indigo coloured, M sized, Parka Jacket
# 693         44       A indigo coloured, L sized, Parka Jacket
# 694         78      A indigo coloured, XL sized, Parka Jacket
# ...        ...                                            ...
# 1219        45  A indigo coloured, XL sized, Pleated Trousers
# 1220        58  A violet coloured, XS sized, Pleated Trousers
# 1221        50   A violet coloured, S sized, Pleated Trousers
# 1222        45   A violet coloured, M sized, Pleated Trousers
# 593         68      A violet coloured, L sized, Bomber Jacket
#
# [1260 rows x 9 columns]

# %%
# make pivot table based on product_type
product_df.groupby("product_type").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price": ["min", "max", "mean"]
})
# Out:
#              product_id quantity price
#                 nunique      sum   min  max        mean
# product_type
# Jacket              420    25387    90  119  107.416667
# Shirt               420    25263    92  119  108.333333
# Trousers            420    25139    90  119  101.666667

# %%
# make pivot table based on product_name
product_df.groupby("product_name").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price": ["min", "max", "mean"]
})
# Out:
#                   product_id quantity price
#                      nunique      sum   min  max   mean
# product_name
# Bomber                    35     2083    90   90   90.0
# Camp Collared             35     2071   112  112  112.0
# Cardigan                  35     2032   118  118  118.0
# Cargo Pants               35     2146   106  106  106.0
# Casual Slim Fit           35     2086   113  113  113.0
# Chambray                  35     2020   105  105  105.0
# Chinos                    35     2101   100  100  100.0
# Coach                     35     2158   115  115  115.0
# Cords                     35     2260   113  113  113.0
# Cropped                   35     2085    99   99   99.0
# Cuban Collar              35     2017    93   93   93.0
# Denim                     70     4204    92  115  103.5
# Drawstring                35     2042   104  104  104.0
# Dress                     35     2125   119  119  119.0
# Flannel                   35     2135    96   96   96.0
# Henley                    35     2051    92   92   92.0
# High-Waisted              35     2198    98   98   98.0
# Joggers                   35     2107    94   94   94.0
# Leather                   35     2276   113  113  113.0
# Linen                     35     2138   116  116  116.0
# Mandarin Collar           35     2203   108  108  108.0
# Oxford Cloth              35     2071   114  114  114.0
# Parka                     35     2201   119  119  119.0
# Peacoat                   35     2067   102  102  102.0
# Pleated                   35     2030    90   90   90.0
# Polo                      35     2196   117  117  117.0
# Puffer                    35     1946   110  110  110.0
# Pullover                  35     2184   114  114  114.0
# Relaxed Leg               35     2002    95   95   95.0
# Shearling                 35     2169    95   95   95.0
# Slim-Fit                  35     2155   119  119  119.0
# Tracksuit Bottoms         35     2038    91   91   91.0
# Trench Coat               35     2132   112  112  112.0
# Windbreaker               35     2085   109  109  109.0
# Wool                      35     1975   111  111  111.0

# %%
# merge product_df to sales_df
sales_product_df = pd.merge(
    left=sales_df,
    right=product_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sales_product_df.head()
# Out:
#    Unnamed: 0_x  sales_id  order_id  product_id  price_per_unit  quantity_x  \
# 0             0         0         1         218             106           2
# 1             1         1         1         481             118           1
# 2             2         2         1           2              96           3
# 3             3         3         1        1002             106           2
# 4             4         4         1         691             113           3
#
#    total_price  Unnamed: 0_y product_type  product_name size  colour  price  \
# 0          212           219        Shirt      Chambray    L  orange    105
# 1          118           485       Jacket        Puffer    S  indigo    110
# 2          288             2        Shirt  Oxford Cloth    M     red    114
# 3          212          1008     Trousers          Wool    M    blue    111
# 4          339           697       Jacket         Parka    S  indigo    119
#
#    quantity_y                                  description
# 0          44   A orange coloured, L sized, Chambray Shirt
# 1          62    A indigo coloured, S sized, Puffer Jacket
# 2          54  A red coloured, M sized, Oxford Cloth Shirt
# 3          52      A blue coloured, M sized, Wool Trousers
# 4          53     A indigo coloured, S sized, Parka Jacket

# %%
# make pivot table based on product_type
sales_product_df.groupby("product_type").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#               sales_id  quantity_x  total_price
# product_type
# Jacket            1676        3343       357026
# Shirt             1641        3259       333600
# Trousers          1683        3360       341174

# %%
# make pivot table based on product_name
sales_product_df.groupby("product_name").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="quantity_x", ascending=False)
# Out:
#                    sales_id  quantity_x  total_price
# product_name
# Denim                   273         527        52399
# Joggers                 164         334        31062
# Pleated                 147         308        32340
# Casual Slim Fit         154         306        36414
# Shearling               150         302        35334
# Relaxed Leg             146         301        27090
# Trench Coat             146         299        35581
# Puffer                  140         298        35164
# Bomber                  150         297        29700
# Chambray                141         290        30740
# Oxford Cloth            146         289        27744
# Drawstring              147         288        27648
# Slim-Fit                154         288        27936
# Windbreaker             143         287        29274
# Cropped                 135         284        32660
# Flannel                 141         281        33158
# Henley                  146         281        26414
# Camp Collared           139         279        27342
# High-Waisted            140         278        27522
# Pullover                143         276        25116
# Linen                   131         270        24570
# Parka                   134         269        30397
# Cargo Pants             134         267        27234
# Peacoat                 132         266        28994
# Coach                   134         265        24645
# Polo                    131         264        25080
# Leather                 136         263        25774
# Chinos                  135         260        29380
# Cardigan                134         260        29120
# Tracksuit Bottoms       130         257        28784
# Cuban Collar            122         254        26670
# Wool                    125         249        26394
# Cords                   126         246        23124
# Dress                   127         243        25272
# Mandarin Collar         124         236        25724

# %%
# merge/join 4 table
all_df = pd.merge(
    left=sales_product_df,
    right=order_customer_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

# drop useless columns
all_df = all_df.drop(["Unnamed: 0_x_x", "Unnamed: 0_y_x"], axis=1)
all_df.head(5)
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  ...  customer_name  \
# 0        Shirt      Chambray    L  orange  ...       fulan 64
# 1       Jacket        Puffer    S  indigo  ...       fulan 64
# 2        Shirt  Oxford Cloth    M     red  ...       fulan 64
# 3     Trousers          Wool    M    blue  ...       fulan 64
# 4       Jacket         Parka    S  indigo  ...       fulan 64
#
#               gender age               home_address  zip_code            city  \
# 0  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 1  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 2  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 3  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 4  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
#
#              state    country  status  age_group
# 0  South Australia  Australia  Active     Senior
# 1  South Australia  Australia  Active     Senior
# 2  South Australia  Australia  Active     Senior
# 3  South Australia  Australia  Active     Senior
# 4  South Australia  Australia  Active     Senior
#
# [5 rows x 30 columns]

# %%
# make pivot table based on state and product_type
all_df.groupby(by=["state", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Australian Capital Territory Jacket               406        43204
#                              Shirt                396        40448
#                              Trousers             454        46790
# New South Wales              Jacket               451        47998
#                              Shirt                431        43980
#                              Trousers             392        39766
# Northern Territory           Jacket               365        38991
#                              Shirt                336        33865
#                              Trousers             384        38998
# Queensland                   Jacket               499        53511
#                              Shirt                417        42506
#                              Trousers             453        46045
# South Australia              Jacket               461        49090
#                              Shirt                509        52685
#                              Trousers             455        46041
# Tasmania                     Jacket               412        44370
#                              Shirt                387        39668
#                              Trousers             379        38057
# Victoria                     Jacket               359        38203
#                              Shirt                390        40206
#                              Trousers             414        41948
# Western Australia            Jacket               390        41659
#                              Shirt                393        40242
#                              Trousers             429        43529

# %%
# make pivot table based on gender and product_type
all_df.groupby(by=["gender", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Female            Jacket               481        50963
#                   Shirt                445        45146
#                   Trousers             481        49295
# Male              Jacket               480        50978
#                   Shirt                410        41939
#                   Trousers             453        46071
# Prefer not to say Jacket              2382       255085
#                   Shirt               2404       246515
#                   Trousers            2426       245808

# %%
# make pivot table based on age_group and product_type
all_df.groupby(by=["age_group", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                         quantity_x  total_price
# age_group product_type
# Adult     Jacket              2292       245055
#           Shirt               2225       227781
#           Trousers            2272       231271
# Senior    Jacket               777        82959
#           Shirt                733        74977
#           Trousers             766        77471
# Youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432

# %%
# DATA EXPLANATORY & DATA VISUALIZATION

# %%
# make a new df from all_df to see monthly order
monthly_order_df = all_df.resample(rule="M", on="order_date").agg({
    "order_id": "nunique",
    "total_price": "sum"
})

# monthly_order_df.index = monthly_order_df.index.strftime("%Y-%m")
monthly_order_df.index = monthly_order_df.index.strftime("%B")    #mengubah format date dalam bulan
monthly_order_df = monthly_order_df.reset_index()
monthly_order_df.rename(columns={
    "order_id": "order_count",
    "total_price": "revenue"
}, inplace=True)
monthly_order_df
# Out:
#   order_date  order_count  revenue
# 0    January          109   119333
# 1   February           93    95080
# 2      March          117   131364
# 3      April           99    97530
# 4        May           84    85597
# 5       June          102   101458
# 6       July          105   116081
# 7     August          106   104565
# 8  September           98    96526
# 9    October           80    84266

# %%
# make a line chart data viz number of order per month based on the monthly_order_df table
plt.figure(figsize=(10, 5))
plt.plot(monthly_order_df["order_date"], monthly_order_df["order_count"], marker="o", linewidth=2, color="#72BCD4")
plt.title("Number OF Order Per Month (2021)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
# make a line chart data viz total revenue per month based on monthly_order_df table
plt.figure(figsize=(10, 5))
plt.plot(monthly_order_df["order_date"], monthly_order_df["revenue"],marker="o", linewidth=2, color="#72BCD4")
plt.title("Total Revenue Per Month (2021)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
# make pivot table to know most sold and least sold product
sum_order_items_df = all_df.groupby("product_name").quantity_x.sum().sort_values(ascending=False).reset_index()
sum_order_items_df
# Out:
#          product_name  quantity_x
# 0               Denim         527
# 1             Joggers         334
# 2             Pleated         308
# 3     Casual Slim Fit         306
# 4           Shearling         302
# 5         Relaxed Leg         301
# 6         Trench Coat         299
# 7              Puffer         298
# 8              Bomber         297
# 9            Chambray         290
# 10       Oxford Cloth         289
# 11         Drawstring         288
# 12           Slim-Fit         288
# 13        Windbreaker         287
# 14            Cropped         284
# 15            Flannel         281
# 16             Henley         281
# 17      Camp Collared         279
# 18       High-Waisted         278
# 19           Pullover         276
# 20              Linen         270
# 21              Parka         269
# 22        Cargo Pants         267
# 23            Peacoat         266
# 24              Coach         265
# 25               Polo         264
# 26            Leather         263
# 27             Chinos         260
# 28           Cardigan         260
# 29  Tracksuit Bottoms         257
# 30       Cuban Collar         254
# 31               Wool         249
# 32              Cords         246
# 33              Dress         243
# 34    Mandarin Collar         236

# %%
# make 2 canvas viz in one set
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

# best performing product
sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0], legend=False)
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis="y", labelsize=12)

# worst performing product
sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.sort_values(by="quantity_x", ascending=True).head(5), palette=colors, ax=ax[1], legend=False)
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis="y", labelsize=12)

plt.suptitle("Best and Worst Performing Product By Number Of Sales", fontsize=20)
plt.show()
# Out:
# /tmp/ipykernel_17353/981472325.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0], legend=False)
# /tmp/ipykernel_17353/981472325.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.sort_values(by="quantity_x", ascending=True).head(5), palette=colors, ax=ax[1], legend=False)

# %%
# make demography by gender
bygender_df = all_df.groupby("gender").customer_id.nunique().reset_index()
bygender_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)

plt.figure(figsize=(10, 5))

sns.barplot(y="customer_count", x="gender", data=bygender_df.sort_values(by="customer_count", ascending=False), palette=colors)
plt.title("Number Of Customer By Gender", loc="center", fontsize=15)
plt.xlabel(None)
plt.ylabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()
# Out:
# /tmp/ipykernel_17353/860121935.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="customer_count", x="gender", data=bygender_df.sort_values(by="customer_count", ascending=False), palette=colors)
# /tmp/ipykernel_17353/860121935.py:9: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(y="customer_count", x="gender", data=bygender_df.sort_values(by="customer_count", ascending=False), palette=colors)

# %% [raw]
# # make demografi by age
# byage_df = all_df.groupby("age_group").customer_id.nunique().reset_index()
# byage_df.rename(columns={
#     "customer_id": "customer_count"
# }, inplace=True)
# byage_df.head()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 byage_df.head()
#
# NameError: name 'byage_df' is not defined
